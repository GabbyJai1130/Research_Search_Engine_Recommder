# %%
import numpy as np
import pandas as pd 
import requests 
import json

import re 

import scrapy
from scrapy.crawler import CrawlerProcess 
from scrapy.selector import HtmlXPathSelector
from bs4 import BeautifulSoup
from scipy.sparse.linalg import svds
from collections import Counter

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ## Scraping restaurants

# %%
headers = {
            'accept-encoding': 'gzip, deflate, sdch, br',
            'accept-language': 'en-US,en;q=0.8,zh-CN;q=0.6,zh;q=0.4',
            'upgrade-insecure-requests': '1',
            'user-agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/56.0.2924.87 Safari/537.36',
            'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8',
            'cache-control': 'max-age=0',
        }

url = 'https://www.openrice.com/en/hongkong/restaurants?page='
base_url = 'https://www.openrice.com'
links =[]

# %%
class linksFinder:

    def __init__(self):
        self.base_url = ''
        self.url = ''
        self.headers = {}
        self.restaurants_links = []
        self.restaurants_info = []

    def get_url(self, base_url, url, headers):
        self.base_url = base_url
        self.url = url
        self.headers = headers

    def get_links(self, start_num, end_num):

        for i in range(start_num, end_num):
            link = self.url + str(i)
            request = requests.get(link, headers=self.headers)
            soup = BeautifulSoup(request.text, 'lxml')

            for h2tag in soup.findAll('h2'):
                for atag in h2tag.findAll('a'):
                    link_tail = atag.get('href')
                    full_link = self.base_url + link_tail

                    self.restaurants_links.append(full_link)

        return print('Scraping done!')

    def save_links(self):
        with open('restaurants_links.txt', 'w') as output_file:
            for link in self.restaurants_links:
                output_file.write(link + '\n')

    def get_restaurants_info(self):
        for link in self.restaurants_links:
            request = requests.get(link, headers=self.headers)
            soup = BeautifulSoup(request.text, 'lxml')

            name = soup.find('div', {'class': 'poi-name'}).find('span').get_text()
            cuisine = soup.find('div', {'class': 'header-poi-categories dot-separator'}).get_text().strip().split('\n')
            rating = soup.find('div', {'class': 'header-score'}).get_text()
            rating = float(rating)

            bookmark = soup.find('div', {'class': 'header-bookmark-count js-header-bookmark-count'}).get_text()
            bookmark = int(bookmark)

            address = soup.find('div', {'class': 'content'}).find('a').get_text().strip()
            district = soup.find('div', {'class': 'header-poi-district dot-separator'}).get_text().split('\n')[1]

            price = soup.find('div', {'class': 'header-poi-price dot-separator'}).get_text().strip()

            review = soup.find('div', {'class': 'main-menu table-center'}).find_all('a', href=True)[1].get_text()
            review_count = re.search(r'\d+', review).group()
            review_count = int(review_count)

            happy = soup.find('div', {'class': 'header-smile-section'}).get_text().split('\n')[2]
            happy = int(happy)
            okay = soup.find('div', {'class': 'header-smile-section'}).get_text().split('\n')[4]
            okay = int(okay)
            sad = soup.find('div', {'class': 'header-smile-section'}).get_text().split('\n')[6]
            sad = int(sad)

            all_items = soup.find_all('div', {'class': 'condition-item'})
            condition_item_avail = []
            for item in all_items:
                check_class = item.find('span').get('class')[1]
                condition = item.find('span', {'class': 'condition-name'}).get_text()
                if check_class == 'd_sr2_lhs_tick_desktop':
                    condition_item_avail.append(condition)

            info = {
                "name": name,
                "cuisine": cuisine,
                "rating": rating,
                "bookmark": bookmark,
                "price-range": price,
                "address": address,
                "district": district,
                "review_count": review_count,
                "review_happy": happy,
                "review_okay": okay,
                "review_sad": sad,
                "available_condition": condition_item_avail
            }

            self.restaurants_info.append(info)

        return print('all restaurant info is scraped!')

    def save_json(self):

        with open('restaurants_info.json', 'w') as file:
            json.dump(self.restaurants_info, file, indent=4, separators=(',', ':'))

        return print('the json file is saved!')

# %%
Finder = linksFinder()

Finder.get_url(base_url, url, headers)
Finder.get_links(start_num=1, end_num=30)

Finder.save_links()
Finder.get_restaurants_info()
Finder.save_json()

# %%
restaurant_info
# Out:
# [{'name': 'Burgeroom',
#   'cuisine': ['American', 'Hamburger', 'Fast Food'],
#   'rating': 4,
#   'bookmark': 46366,
#   'price-range': '$51-100',
#   'address': 'Shop D, G/F, Food Street, 50-56 Paterson Street, Fashion Walk, Causeway Bay',
#   'district': 'Causeway Bay',
#   'review_count': 1272,
#   'review_happy': 1032,
#   'review_okay': 112,
#   'review_sad': 63,
#   'available_condition': ['Alcoholic Drinks',
#    'May Bring Your Own Wine',
#    'Cake-cutting',
#    'Parking',
#    'Delivery',
#    'Outdoor Seating',
#    'Spot payment']},
#  {'name': '心之食堂',
#   'cuisine': ['Japanese',
#    'International',
#    'Sushi/Sashimi',
#    'Skewer',
#    'Izakaya'],
#   'rating': 4,
#   'bookmark': 15567,
#   'price-range': '$201-400',
#   'address': 'Room 1203, 12/F, Bartlock Centre, 3 Yiu Wa Street, Causeway Bay',
#   'district': 'Causeway Bay',
#   'review_count': 894,
#   'review_happy': 780,
#   'review_okay': 47,
#   'review_sad': 27,
#   'available_condition': ['Online Reservation',
#    'Wi-Fi',
#    'Open Till Late',
#    'Alcoholic Drinks',
#    'May Bring Your Own Wine',
#    'Cake-cutting',
#    'Phone Reservation',
#    'Reward Dining Points',
#    'Delivery',
#    '10% Service Charge',
#    'TV Broadcast',
#    'Spot payment']},
#  {'name': 'Burgeroom',
#   'cuisine': ['American', 'Hamburger', 'Fast Food'],
#   'rating': 4.0,
#   'bookmark': 46366,
#   'price-range': '$51-100',
#   'address': 'Shop D, G/F, Food Street, 50-56 Paterson Street, Fashion Walk, Causeway Bay',
#   'district': 'Causeway Bay',
#   'review_count': 1272,
#   'review_happy': 1032,
#   'review_okay': 112,
#   'review_sad': 63,
#   'available_condition': ['Alcoholic Drinks',
#    'May Bring Your Own Wine',
#    'Cake-cutting',
#    'Parking',
#    'Delivery',
#    'Outdoor Seating',
#    'Spot payment']},
#  {'name': '心之食堂',
#   'cuisine': ['Japanese',
#    'International',
#    'Sushi/Sashimi',
#    'Skewer',
#    'Izakaya'],
#   'rating': 4.0,
#   'bookmark': 15567,
#   'price-range': '$201-400',
#   'address': 'Room 1203, 12/F, Bartlock Centre, 3 Yiu Wa Street, Causeway Bay',
#   'district': 'Causeway Bay',
#   'review_count': 894,
#   'review_happy': 780,
#   'review_okay': 47,
#   'review_sad': 27,
#   'available_condition': ['Online Reservation',
#    'Wi-Fi',
#    'Open Till Late',
#    'Alcoholic Drinks',
#    'May Bring Your Own Wine',
#    'Cake-cutting',
#    'Phone Reservation',
#    'Reward Dining Points',
#    'Delivery',
#    '10% Service Charge',
#    'TV Broadcast',
#    'Spot payment']},
#  {'name': '鉄人旨花',
#   'cuisine': ['Japanese', 'Teppanyaki', 'Sushi/Sashimi', 'Omakase'],
#   'rating': 4.5,
#   'bookmark': 16798,
#   'price-range': 'Above $801',
#   'address': '2/F, Shining building, 477-481 Jaffe Road, Causeway Bay',
#   'district': 'Causeway Bay',
#   'review_count': 1058,
#   'review_happy': 1012,
#   'review_okay': 16,
#   'review_sad': 11,
#   'available_condition': ['Alcoholic Drinks',
#    'May Bring Your Own Wine',
#    'Cake-cutting',
#    '10% Service Charge']},
#  {'name': 'Bingo & Cook',
#   'cuisine': ['Korean', 'Korean Fried Chicken'],
#   'rating': 4.0,
#   'bookmark': 23564,
#   'price-range': '$101-200',
#   'address': "2/F, L'Hart, 487-489 Lockhart Road, Causeway Bay",
#   'district': 'Causeway Bay',
#   'review_count': 946,
#   'review_happy': 825,
#   'review_okay': 57,
#   'review_sad': 13,
#   'available_condition': ['Online Reservation',
#    'Wi-Fi',
#    'May Bring Your Own Wine',
#    'Cake-cutting',
#    'Phone Reservation',
#    'Reward Dining Points',
#    'Delivery',
#    '10% Service Charge']},
#  {'name': '炊豕店',
#   'cuisine': ['Hong Kong Style', 'Taiwan', 'Snack Shop & Deli'],
#   'rating': 4.0,
#   'bookmark': 31252,
#   'price-range': 'Below $50',
#   'address': 'G/F, 11 Caroline Hill Road, Causeway Bay',
#   'district': 'Causeway Bay',
#   'review_count': 666,
#   'review_happy': 533,
#   'review_okay': 45,
#   'review_sad': 26,
#   'available_condition': ['Delivery']},
#  {'name': 'Dodam Chicken',
#   'cuisine': ['Korean', 'Korean Fried Chicken'],
#   'rating': 4.0,
#   'bookmark': 23213,
#   'price-range': '$101-200',
#   'address': '18/F., Shop A, Lee Theatre Plaza, 99 Percival Street, Causeway Bay',
#   'district': 'Causeway Bay',
#   'review_count': 789,
#   'review_happy': 665,
#   'review_okay': 53,
#   'review_sad': 17,
#   'available_condition': ['Online Reservation',
#    'Wi-Fi',
#    'Alcoholic Drinks',
#    'Parking',
#    'Phone Reservation',
#    'Reward Dining Points',
#    'Delivery',
#    'Spot payment']},
#  {'name': 'Seoulmate Cafe',
#   'cuisine': ['Korean',
#    'International',
#    'Dessert',
#    'Korean Fried Chicken',
#    'Upper-floor Cafe'],
#   'rating': 4.0,
#   'bookmark': 33325,
#   'price-range': '$101-200',
#   'address': '4/F, Kyoto Plaza, 491-499 Lockhart Road, Causeway Bay',
#   'district': 'Causeway Bay',
#   'review_count': 879,
#   'review_happy': 700,
#   'review_okay': 85,
#   'review_sad': 32,
#   'available_condition': ['Online Reservation',
#    'Wi-Fi',
#    'Alcoholic Drinks',
#    'May Bring Your Own Wine',
#    'Cake-cutting',
#    'VIP Room',
#    'Phone Reservation',
#    'Reward Dining Points',
#    'Delivery',
#    '10% Service Charge',
#    'Outdoor Seating',
#    'Spot payment']},
#  {'name': 'Sodam Chicken',
#   'cuisine': ['Korean', 'Korean Fried Chicken'],
#   'rating': 4.0,
#   'bookmark': 37240,
#   'price-range': '$101-200',
#   'address': '7/F, 3 Yiu Wa Street, Bartlock Centre, Causeway Bay',
#   'district': 'Causeway Bay',
#   'review_count': 1013,
#   'review_happy': 789,
#   'review_okay': 92,
#   'review_sad': 43,
#   'available_condition': ['Online Reservation',
#    'Alcoholic Drinks',
#    'Parking',
#    'Phone Reservation',
#    'Reward Dining Points',
#    'Delivery',
#    '10% Service Charge',
#    'Spot payment']},
#  {'name': '漁獲浜燒',
#   'cuisine': ['Japanese'],
#   'rating': 4.5,
#   'bookmark': 26753,
#   'price-range': '$201-400',
#   'address': '18/F, Macau Yat Yuen Centre, 525 Hennessy Road, Causeway Bay',
#   'district': 'Causeway Bay',
#   'review_count': 732,
#   'review_happy': 698,
#   'review_okay': 10,
#   'review_sad': 5,
#   'available_condition': ['Online Reservation',
#    'Wi-Fi',
#    'Alcoholic Drinks',
#    'May Bring Your Own Wine',
#    'Cake-cutting',
#    'VIP Room',
#    'Phone Reservation',
#    'Reward Dining Points',
#    '10% Service Charge']},
#  {'name': 'Mamaday',
#   'cuisine': ['International',
#    'All Day Breakfast',
#    'Coffee Shop',
#    'Upper-floor Cafe'],
#   'rating': 4.0,
#   'bookmark': 31848,
#   'price-range': '$101-200',
#   'address': '1/F, Perfect Commercial Building, 28 Sharp Street West, Causeway Bay',
#   'district': 'Causeway Bay',
#   'review_count': 513,
#   'review_happy': 400,
#   'review_okay': 53,
#   'review_sad': 8,
#   'available_condition': ['Wi-Fi',
#    'Alcoholic Drinks',
#    'Cake-cutting',
#    'Phone Reservation',
#    '10% Service Charge']},
#  {'name': 'Mad for Garlic',
#   'cuisine': ['Korean', 'Italian', 'Pizza'],
#   'rating': 4.0,
#   'bookmark': 19940,
#   'price-range': '$101-200',
#   'address': 'Shop 1104, 11/F, Food Forum, Times Square, 1 Matheson Street, Causeway Bay',
#   'district': 'Causeway Bay',
#   'review_count': 657,
#   'review_happy': 546,
#   'review_okay': 57,
#   'review_sad': 16,
#   'available_condition': ['Online Reservation',
#    'Wi-Fi',
#    'Alcoholic Drinks',
#    'May Bring Your Own Wine',
#    'Cake-cutting',
#    'Phone Reservation',
#    'Reward Dining Points',
#    '10% Service Charge',
#    'Spot payment']},
#  {'name': 'Little Vegas',
#   'cuisine': ['Western',
#    'Pizza',
#    'Hamburger',
#    'All Day Breakfast',
#    'Upper-floor Cafe',
#    'Theme Restaurant'],
#   'rating': 4.0,
#   'bookmark': 36643,
#   'price-range': '$101-200',
#   'address': '25/F, Bartlock Centre, 3 Yiu Wa Street, Causeway Bay',
#   'district': 'Causeway Bay',
#   'review_count': 805,
#   'review_happy': 631,
#   'review_okay': 104,
#   'review_sad': 27,
#   'available_condition': ['Wi-Fi',
#    'Cake-cutting',
#    'Eco-Friendly',
#    'Parking',
#    'Phone Reservation',
#    '10% Service Charge',
#    'Spot payment']},
#  {'name': 'FireBird',
#   'cuisine': ['Japanese', 'Skewer', 'Izakaya'],
#   'rating': 4.0,
#   'bookmark': 16058,
#   'price-range': '$201-400',
#   'address': 'G/F, Hotel Pennington by Rhombus, 13 Pennington Street, Causeway Bay',
#   'district': 'Causeway Bay',
#   'review_count': 552,
#   'review_happy': 496,
#   'review_okay': 19,
#   'review_sad': 14,
#   'available_condition': ['Online Reservation',
#    'Alcoholic Drinks',
#    'May Bring Your Own Wine',
#    'Cake-cutting',
#    'Phone Reservation',
#    'Reward Dining Points',
#    'Delivery',
#    '10% Service Charge']},
#  {'name': "Mr. Crab by The Captain's House",
#   'cuisine': ['Western',
#    'American',
#    'Seafood',
#    'Oyster Bar',
#    'Crab Specialty'],
#   'rating': 4.0,
#   'bookmark': 20468,
#   'price-range': '$101-200',
#   'address': 'Shop C, G/F-1/F, 74-78 Johnstan Road, Wan Chai',
#   'district': 'Wan Chai',
#   'review_count': 629,
#   'review_happy': 551,
#   'review_okay': 32,
#   'review_sad': 19,
#   'available_condition': ['Online Reservation',
#    'Reward Dining Points',
#    '10% Service Charge',
#    'Spot payment']},
#  {'name': 'Check-In Taipei',
#   'cuisine': ['Taiwan', 'Taiwanese Drink', 'Dessert', 'Bar', 'Tea House'],
#   'rating': 4.0,
#   'bookmark': 28070,
#   'price-range': '$101-200',
#   'address': 'G/F, 27 Hollywood Road, Soho, Central',
#   'district': 'Central',
#   'review_count': 593,
#   'review_happy': 466,
#   'review_okay': 61,
#   'review_sad': 28,
#   'available_condition': ['Online Reservation',
#    'Wi-Fi',
#    'Alcoholic Drinks',
#    'May Bring Your Own Wine',
#    'Cake-cutting',
#    'Phone Reservation',
#    'Reward Dining Points',
#    '10% Service Charge',
#    'Spot payment']}]

# %% [markdown]
# ## Processing restaurant info
#
# Because the scrapped information of restaurant is not ideal for later steps, I need to perform processing first
#
# For testing purpose, I import the scrapped json document, which is stored in my local drive

# %%
df = pd.DataFrame()

df = pd.read_json('restaurants_info.json')

df.shape
# Out:
# (370, 12)

# %% [markdown]
# As it turns out, the openrice restaurant is not good for scraping a wide range of pages it will re-cycle restaurants in later pages

# %%
df.drop_duplicates(['name','address'],inplace = True)
df.shape
# Out:
# (250, 12)

# %%
def unpack_cuisine(source, target = 3, defaultValue=None):
    n = len(source)
    if n < target:
        return [*source, *([defaultValue] * (target - len(source)))]
    elif n > target:
        return source[0:target]
    else:
        return source

# %%
df['cuisine_main_type'], df['cuisine_sub_type'], df['cuisine_minor_type'] = zip(*df['cuisine'].apply(lambda x: unpack_cuisine(x)))
df.drop('cuisine',axis = 1, inplace = True)

columns = ['name',
           'address',
           'district',
           'cuisine_main_type', 
           'cuisine_sub_type',
           'cuisine_minor_type',
           'available_condition',
           'price-range',
           'rating',
           'bookmark',
           'review_count',
           'review_happy',
           'review_okay',
           'review_sad']

df = df[columns]

# %%
df.tail()
# Out:
#               name                                            address  \
# 245        梨滿園韓國料理  1/F, Witty Commercial Building Deli2, 1A-1L Tu...
# 246        榮哥廚房私房菜  Shop L, 4/F, Phase 3, Kwun Tong Industrial Cen...
# 247  Cafe Paradise            G/F, 412 Portland Street, Prince Edward
# 248           桂花小幸  Shop 133-135, 1/F, TKO Plaza, 1 Tong Tak Stree...
# 249     家賀屋刺身寿司專門店                    1/F, 83 Wan Chai Road, Wan Chai
#
#           district cuisine_main_type cuisine_sub_type cuisine_minor_type  \
# 245       Mong Kok            Korean       Korean BBQ               None
# 246      Kwun Tong         Guangdong    International           Stir-Fry
# 247  Prince Edward           Italian          Western            Dessert
# 248  Tseung Kwan O            Taiwan  Taiwanese Drink               None
# 249       Wan Chai          Japanese    Sushi/Sashimi               None
#
#                                    available_condition price-range  rating  \
# 245  [Online Reservation, Wi-Fi, Alcoholic Drinks, ...    $101-200     4.0
# 246  [Online Reservation, Wi-Fi, Alcoholic Drinks, ...    $201-400     4.5
# 247  [Online Reservation, Alcoholic Drinks, Cake-cu...     $51-100     4.0
# 248                                     [Spot payment]     $51-100     4.0
# 249  [Alcoholic Drinks, Phone Reservation, Catering...    $101-200     4.0
#
#      bookmark  review_count  review_happy  review_okay  review_sad
# 245     10424           521           452           25          16
# 246     12136           335           304            7           6
# 247      8795           355           316           14           4
# 248      4154           383           281           49          13
# 249     14669           472           417           16          11

# %% [markdown]
# ## Search engine

# %% [markdown]
# <h3> Filtering option: </h3>
#
# name
#
# name_contain
#
# district
#
# country
#
# dish
#
# available condition:
#
#  ['Online Reservation',
#  'Wi-Fi',
#  'Alcoholic Drinks',
#  'May Bring Your Own Wine',
#  'Cake-cutting',
#  'VIP Room',
#  'Phone Reservation',
#  'Reward Dining Points',
#  '10% Service Charge',
#  'Parking',
#  'Delivery',
#  'Spot payment',
#  'Outdoor Seating',
#  'Open Till Late',
#  'TV Broadcast',
#  'Exclusive Online Booking',
#  'Sea View',
#  'Live Music',
#  'Smoking Area',
#  'Eco-Friendly',
#  'Live Sports Broadcast',
#  'Vegetarian',
#  'Certified Halal Food',
#  'All You Can Eat Hotpot',
#  'Catering Service']
#
# price_range:
#
# Below 50, 51-100, 101-200, 201-400, 401-800, Above 801

# %%
class searchEngine:

    def __init__(self):
        self.df = pd.DataFrame()

    def get_json(self, json_doc):

        self.df = pd.read_json(json_doc)
        self.df.drop_duplicates(['name', 'address'], inplace=True)

        def unpack_cuisine(source, target=3, defaultValue=None):
            n = len(source)
            if n < target:
                return [*source, *([defaultValue] * (target - len(source)))]
            elif n > target:
                return source[0:target]
            else:
                return source

        self.df['cuisine_main_type'], self.df['cuisine_sub_type'], self.df['cuisine_minor_type'] = zip(
            *self.df['cuisine'].apply(lambda x: unpack_cuisine(x)))
        self.df.drop('cuisine', axis=1, inplace=True)

        columns = ['name',
                   'address',
                   'district',
                   'cuisine_main_type',
                   'cuisine_sub_type',
                   'cuisine_minor_type',
                   'available_condition',
                   'price-range',
                   'rating',
                   'bookmark',
                   'review_count',
                   'review_happy',
                   'review_okay',
                   'review_sad']

        self.df = self.df[columns]

    def search(self, filter_select):
        restaurant_list = self.df.copy()
        restaurant_to_remove = []

        if 'name' in filter_select:

            for i in range(len(self.df)):
                if filter_select['name'] != self.df['name'][i]:
                    restaurant_to_remove.append(i)

        if 'name_contain' in filter_select:

            for i in range(len(self.df)):
                flag = 0
                for pattern in range(len(filter_select['name_contain'])):
                    if re.search(filter_select['name_contain'][pattern], self.df['name'][i]):
                        break
                if flag == 0:
                    restaurant_to_remove.append(i)

        if 'country' in filter_select:

            for i in range(len(self.df)):
                if filter_select['country'] != self.df['cuisine_main_type'][i]:
                    restaurant_to_remove.append(i)

        if 'dish' in filter_select:

            for i in range(len(self.df)):
                if filter_select['dish'] != self.df['cuisine_sub_type'][i] and \
                        filter_select['dish'] != self.df['cuisine_minor_type'][i]:
                    restaurant_to_remove.append(i)

        if 'avail_cond' in filter_select:

            for i in range(len(self.df)):
                cond_count = len(self.df['available_condition'][i])
                for option in filter_select['avail_cond']:
                    if option not in self.df['available_condition'][i]:
                        cond_count = cond_count - 1

                if cond_count <= 0:
                    restaurant_to_remove.append(i)

        if 'price range' in filter_select:

            min_range = int(filter_select['price range'][0:filter_select['price range'].find('-')])

            max_range = int(filter_select['price range'][filter_select['price range'].find('-') + 1:])

            for i in range(len(self.df)):
                if self.df['price-range'][i] == 'Below $50':
                    price_min = 0
                    price_max = 50
                elif self.df['price-range'][i] == '$51-100':
                    price_min = 51
                    price_max = 100
                elif self.df['price-range'][i] == '$101-200':
                    price_min = 101
                    price_max = 200
                elif self.df['price-range'][i] == '$201-400':
                    price_min = 201
                    price_max = 400
                elif self.df['price-range'][i] == '$401-800':
                    price_min = 401
                    price_max = 800
                elif self.df['price-range'][i] == 'Above $801':
                    price_min = 801
                    price_max = 10000

                if price_min < min_range or price_max > max_range:
                    restaurant_to_remove.append(i)

        for index_remove in set(restaurant_to_remove):
            restaurant_list.drop(index=index_remove, axis=0, inplace=True)

        return restaurant_list

    def top_N_similar(self, restaurant, district, n):
        scale = StandardScaler()
        list_similar = []

        if (restaurant != None) & (district == None):
            target_idx = self.df[self.df['name'] == restaurant].index[0]

        elif (restaurant == None) & (district != None):
            target_idx = self.df[self.df['district'] == district].index[0]

        else:
            target_idx = self.df[(self.df['name'] == restaurant) & (self.df['district'] == district)].index[0]

        n = (n + 1) * -1

        df_avail_cond = self.df['available_condition'].str.join('|').str.get_dummies()
        df_sim = pd.concat([self.df, df_avail_cond], axis=1)
        df_sim.drop(['available_condition'], axis=1, inplace=True)

        df_sim_matrix = df_sim.drop(['name', 'address'], axis=1)
        df_sim_matrix = pd.get_dummies(df_sim_matrix, drop_first=True)

        df_sim_matrix.iloc[:, :6] = scale.fit_transform(df_sim_matrix.iloc[:, :6])

        df_sim['similarity'] = list(cosine_similarity(df_sim_matrix, dense_output=True))

        top_n_indices = np.argsort(df_sim['similarity'][target_idx])[n:]
        top_n_indices = top_n_indices[:-1]

        for index in top_n_indices:
            list_similar.append(self.df.iloc[index, :])

        df_sim_results = pd.DataFrame(list_similar)

        return df_sim_results

        return restaurant_list

# %%
engine = searchEngine()
engine.get_json('restaurants_info.json')

results = engine.search({'country': 'Japanese',
                           'avail_cond':['Online Reservation','Alcoholic Drinks','Phone Reservation']})

# %%
result
# Out:
#                             name  \
# 5                           心之食堂
# 7                           鉄人旨花
# 11                        七福神和食亭
# 19                          漁獲浜燒
# 21   Day and Nite by Master Kama
# 31                        嵐山日本料理
# 39                          焱丸水產
# 42                      FireBird
# 43                       和匠日式燒肉店
# 44                     極尚大喜屋日本料理
# 45                        鮨一日本料理
# 53                           掌壽司
# 61                          磯野水產
# 62                     殿 大喜屋日本料理
# 63                         鳥居居酒屋
# 69                            琥酌
# 71                    S2 Kitchen
# 75                           串酒里
# 79                     極尚大瀛喜日本料理
# 98                             宏
# 99                       大本瀛日式放題
# 112                       岩鹽日本料理
# 113                       和牛燒肉‧純
# 116                         深宵食堂
# 123                           鮨文
# 125                           初見
# 128                    極尚大瀛喜日本料理
# 137                    樂天大喜屋日本料理
# 141                      大滿喜日本料理
# 145                       S2 鐵板燒
# 169                      大瀛喜日本料理
# 174                           丼瀛
# 175                       吉壽日本料理
# 178                         德美壽司
# 179                           琥酌
# 204                           鮨真
# 206                       築地日本料理
# 209                    Steak Bar
# 210                          古今二
# 224                          風雲丸
# 229                           備長
# 240                           浜滝
# 241                      元祖沾麵專門店
# 243                       味道樂居酒屋
# 249                   家賀屋刺身寿司專門店
#
#                                                address        district  \
# 5    Room 1203, 12/F, Bartlock Centre, 3 Yiu Wa Str...    Causeway Bay
# 7    2/F, Shining building, 477-481 Jaffe Road, Cau...    Causeway Bay
# 11                    1/F, 311-313 Nathan Road, Jordan          Jordan
# 19   18/F, Macau Yat Yuen Centre, 525 Hennessy Road...    Causeway Bay
# 21                  1/F, 50 Shan Tung Street, Mong Kok        Mong Kok
# 31                G/F, 11 Minden Avenue, Tsim Sha Tsui   Tsim Sha Tsui
# 39   Shop 5&6, G/F, Wah Fung Building, 23 Minden Av...   Tsim Sha Tsui
# 42   G/F, Hotel Pennington by Rhombus, 13 Penningto...    Causeway Bay
# 43   Shop 3, G/F, Tak Wai Building, 23-27 Cheong Lo...          Jordan
# 44   Shop 102, 1/F, Albion Plaza, 2-6 Granville Roa...   Tsim Sha Tsui
# 45   18/F, The Lamma Tower, 12 Hau Fook Street, Tsi...   Tsim Sha Tsui
# 53   Flat U, 5/F, Block 3, Camel Paint Buildings, 6...       Kwun Tong
# 61   19/F, Macau Yat Yuen Centre, 525 Hennessy Road...    Causeway Bay
# 62               1/F, 26 Kimberley Road, Tsim Sha Tsui   Tsim Sha Tsui
# 63   17/F, Macau Yat Yuen Centre, 525 Hennessy Road...    Causeway Bay
# 69   G/F, 159A Sai Yeung Choi Street North, Prince ...   Prince Edward
# 71          Shop A, G/F, 51 Wellington Street, Central         Central
# 75        Shop B, G/F,  6 Hillwood Road, Tsim Sha Tsui   Tsim Sha Tsui
# 79   11/F, Causeway Bay Plaza 2, 463-483 Lockhart R...    Causeway Bay
# 98   Shop 502, 5/F, The ONE, 100 Nathan Road, Tsim ...   Tsim Sha Tsui
# 99   10/F, CTMA Centre, 1 Sai Yeung Choi Street, Mo...        Mong Kok
# 112  ShopA, 16/F, Lee Theatre Plaza, 99 Percival St...    Causeway Bay
# 113  Shop 3,1/F, Hilton Towers, 96 Granville Road, ...   Tsim Sha Tsui
# 116  6/F, Bartlock Centre, Yiu Wa Street, Causeway Bay    Causeway Bay
# 123  Shop 5, G/F,Lee Fat House, No. 5 Yan Lok Squar...       Yuen Long
# 125  Shop F, G/F, Wah Tat Building, 22 Hoi Pa Stree...       Tsuen Wan
# 128  5/F, One Pacific Centre, 414 Kwun Tong Road, K...       Kwun Tong
# 137  2/F, Chong Hing Square, 593-601 Nathan Road, M...        Mong Kok
# 141  8/F, Chong Hing Square, 593-601 Nathan Road, M...        Mong Kok
# 145        Shop 6, G/F, 29-37 Wai Ching Street, Jordan          Jordan
# 169         5/F, MPM Plaza, 11 Nelson Street, Mong Kok        Mong Kok
# 174  Flat A, 5/F, Wing Cheung Industrial Building,1...       Kwun Tong
# 175      5/F, Wu Sang House, 655 Nathan Road, Mong Kok        Mong Kok
# 178          5/F, H8, 8 Hau Fook Street, Tsim Sha Tsui   Tsim Sha Tsui
# 179  11/F , 38-40 Haiphong Road, Zhongda Building,,...   Tsim Sha Tsui
# 204            20/F., 17-19 Ashley Road, Tsim Sha Tsui   Tsim Sha Tsui
# 206  Room R1, 7/F, Island Beverley, 1 Great George ...    Causeway Bay
# 209  Shop B, G/F, Tang Fai Building , 36-48 Tang Lu...    Causeway Bay
# 210  Room B, 1/F, Kwun Tong Industrial Centre Phase...       Kwun Tong
# 224  Shop B, G/F, W Square, 314-324 Hennessy Road, ...        Wan Chai
# 229  26/F, Macau Yat Yuen Centre, 525 Hennessy Road...    Causeway Bay
# 240     Shop A, G/F, 59 Fuk Lo Tsun Road, Kowloon City    Kowloon City
# 241  Shop 5, G/F, Dorfu Court, 5-6 Hau Fook Street,...   Tsim Sha Tsui
# 243  Shop C, G/F, Green Court, 498 Un Chau Street, ...  Cheung Sha Wan
# 249                    1/F, 83 Wan Chai Road, Wan Chai        Wan Chai
#
#     cuisine_main_type cuisine_sub_type  cuisine_minor_type  \
# 5            Japanese    International       Sushi/Sashimi
# 7            Japanese       Teppanyaki       Sushi/Sashimi
# 11           Japanese    Sushi/Sashimi                None
# 19           Japanese             None                None
# 21           Japanese          Italian             Seafood
# 31           Japanese    Sushi/Sashimi              Skewer
# 39           Japanese          Seafood       Sushi/Sashimi
# 42           Japanese           Skewer             Izakaya
# 43           Japanese       Roast Meat              Skewer
# 44           Japanese    Sushi/Sashimi     All-you-can-eat
# 45           Japanese    Sushi/Sashimi                Udon
# 53           Japanese    Sushi/Sashimi                None
# 61           Japanese          Seafood       Sushi/Sashimi
# 62           Japanese    Sushi/Sashimi              Skewer
# 63           Japanese       Robatayaki              Skewer
# 69           Japanese       Roast Meat             Izakaya
# 71           Japanese    Sushi/Sashimi              Skewer
# 75           Japanese       Roast Meat              Skewer
# 79           Japanese  All-you-can-eat                None
# 98           Japanese          Dessert             Yoshoku
# 99           Japanese  All-you-can-eat                None
# 112          Japanese          Seafood       Sushi/Sashimi
# 113          Japanese       Roast Meat                None
# 116          Japanese           Skewer             Izakaya
# 123          Japanese    Sushi/Sashimi             Omakase
# 125          Japanese          Hot Pot          Roast Meat
# 128          Japanese  All-you-can-eat                None
# 137          Japanese  All-you-can-eat  Food Wise Eateries
# 141          Japanese  All-you-can-eat                None
# 145          Japanese       Teppanyaki                None
# 169          Japanese  All-you-can-eat                None
# 174          Japanese    Sushi/Sashimi                None
# 175          Japanese  All-you-can-eat                None
# 178          Japanese    Sushi/Sashimi                None
# 179          Japanese       Roast Meat             Izakaya
# 204          Japanese    Sushi/Sashimi                None
# 206          Japanese    Sushi/Sashimi                Udon
# 209          Japanese      Steak House                None
# 210          Japanese    Sushi/Sashimi             Izakaya
# 224          Japanese            Ramen                None
# 229          Japanese           Skewer             Izakaya
# 240          Japanese            Ramen              Skewer
# 241          Japanese            Ramen                None
# 243          Japanese          Izakaya                None
# 249          Japanese    Sushi/Sashimi                None
#
#                                    available_condition price-range  rating  \
# 5    [Online Reservation, Wi-Fi, Open Till Late, Al...    $201-400     4.0
# 7    [Alcoholic Drinks, May Bring Your Own Wine, Ca...  Above $801     4.5
# 11   [Online Reservation, Alcoholic Drinks, May Bri...    $101-200     4.0
# 19   [Online Reservation, Wi-Fi, Alcoholic Drinks, ...    $201-400     4.5
# 21   [Online Reservation, Phone Reservation, Reward...    $101-200     4.0
# 31   [Online Reservation, Wi-Fi, Alcoholic Drinks, ...    $201-400     4.0
# 39   [Online Reservation, Phone Reservation, Reward...    $201-400     4.0
# 42   [Online Reservation, Alcoholic Drinks, May Bri...    $201-400     4.0
# 43   [Online Reservation, Wi-Fi, Alcoholic Drinks, ...    $201-400     4.0
# 44   [Online Reservation, Wi-Fi, Alcoholic Drinks, ...    $201-400     4.0
# 45   [Online Reservation, Wi-Fi, Alcoholic Drinks, ...    $201-400     4.0
# 53   [Online Reservation, Wi-Fi, Parking, Phone Res...    $201-400     4.0
# 61   [Online Reservation, Alcoholic Drinks, Cake-cu...    $201-400     4.5
# 62   [Online Reservation, Wi-Fi, Alcoholic Drinks, ...    $201-400     4.0
# 63   [Online Reservation, Alcoholic Drinks, May Bri...    $201-400     4.0
# 69   [Online Reservation, Alcoholic Drinks, May Bri...    $201-400     4.0
# 71   [Online Reservation, Wi-Fi, Alcoholic Drinks, ...    $401-800     4.0
# 75   [Online Reservation, Alcoholic Drinks, Reward ...    $201-400     4.0
# 79   [Online Reservation, Wi-Fi, Alcoholic Drinks, ...    $201-400     4.0
# 98   [Wi-Fi, Parking, 10% Service Charge, Spot paym...    $101-200     4.0
# 99   [Online Reservation, Wi-Fi, Alcoholic Drinks, ...    $201-400     4.0
# 112  [Alcoholic Drinks, May Bring Your Own Wine, Ca...    $101-200     4.0
# 113  [Wi-Fi, Alcoholic Drinks, May Bring Your Own W...    $401-800     4.5
# 116  [Online Reservation, Open Till Late, Alcoholic...    $201-400     4.0
# 123  [Alcoholic Drinks, May Bring Your Own Wine, Pa...  Above $801     4.5
# 125  [Wi-Fi, Alcoholic Drinks, Parking, Phone Reser...     $51-100     4.0
# 128  [Online Reservation, Wi-Fi, Alcoholic Drinks, ...    $201-400     4.0
# 137  [Online Reservation, Wi-Fi, Alcoholic Drinks, ...    $201-400     4.0
# 141  [Online Reservation, Wi-Fi, Alcoholic Drinks, ...    $201-400     4.0
# 145  [Online Reservation, Open Till Late, Alcoholic...    $401-800     4.5
# 169  [Online Reservation, Wi-Fi, Alcoholic Drinks, ...    $201-400     4.0
# 174  [Online Reservation, May Bring Your Own Wine, ...    $101-200     4.0
# 175  [Online Reservation, Wi-Fi, Alcoholic Drinks, ...    $201-400     4.0
# 178  [Phone Reservation, 10% Service Charge, Spot p...    $101-200     4.0
# 179  [Online Reservation, Wi-Fi, Alcoholic Drinks, ...    $201-400     4.0
# 204  [Alcoholic Drinks, May Bring Your Own Wine, 10...  Above $801     4.5
# 206  [Wi-Fi, Alcoholic Drinks, May Bring Your Own W...    $101-200     4.0
# 209  [Online Reservation, Alcoholic Drinks, Reward ...    $201-400     4.0
# 210  [Online Reservation, Wi-Fi, May Bring Your Own...    $201-400     4.0
# 224            [Wi-Fi, Alcoholic Drinks, Spot payment]     $51-100     4.0
# 229  [Online Reservation, Alcoholic Drinks, May Bri...    $201-400     4.0
# 240  [Online Reservation, Wi-Fi, Open Till Late, Al...    $201-400     4.0
# 241  [Wi-Fi, Alcoholic Drinks, Parking, Phone Reser...    $101-200     3.5
# 243  [Phone Reservation, 10% Service Charge, Spot p...    $101-200     4.0
# 249  [Alcoholic Drinks, Phone Reservation, Catering...    $101-200     4.0
#
#      bookmark  review_count  review_happy  review_okay  review_sad
# 5       15569           894           780           47          27
# 7       16798          1058          1012           16          11
# 11      24945           993           826           72          32
# 19      26754           732           698           10           5
# 21      40880           857           646           89          48
# 31      23243           545           489           24           5
# 39      31248           721           605           42          21
# 42      16058           552           496           19          14
# 43      17805           698           635           26          19
# 44      76447           684           499           55          25
# 45      28850           587           475           26          20
# 53      18094           583           474           41          27
# 61       8485           452           439            5           2
# 62      58506           703           506           85          27
# 63      20823           626           545           22          29
# 69      17746           512           444           26           8
# 71      21934           743           626           24          53
# 75      14255           568           508           20          15
# 79      36508           672           570           37          10
# 98      14558           778           605           76          44
# 99      24606           769           671           22          23
# 112     19487           418           352           22           6
# 113     22838           487           434           19           5
# 116     14357           553           489           27          18
# 123     18424           517           476           13          10
# 125      8485           413           365           19           3
# 128     23251           594           493           29           8
# 137     45702           639           480           56          21
# 141     32986           663           552           43          24
# 145      9724           443           418            4          11
# 169     33739           692           541           64          22
# 174     12013           420           319           18          38
# 175     18040           817           633           70          49
# 178     18419           447           325           60          15
# 179     11422           461           407           23           4
# 204      8160           410           393            4           2
# 206      8498           384           323           28          14
# 209     19281           484           392           28          20
# 210     17845           332           239           57           6
# 224     13615           452           331           52          24
# 229     10230           368           310           21          13
# 240     10902           383           323           18          23
# 241     13545           721           495           72          97
# 243     14095           387           309           36          17
# 249     14669           472           417           16          11

# %% [markdown]
# ## Recommendation system

# %%
df[df['name']=='Yadllie Plate']
# Out:
#             name                                            address  district  \
# 2  Yadllie Plate  11/F, CTMA Centre, 1 Sai Yeung Choi Street, Mo...  Mong Kok
#
#   cuisine_main_type      cuisine_sub_type cuisine_minor_type  \
# 2            Korean  Korean Fried Chicken               None
#
#                                  available_condition price-range  rating  \
# 2  [Online Reservation, Wi-Fi, Alcoholic Drinks, ...    $101-200     4.0
#
#    bookmark  review_count  review_happy  review_okay  review_sad
# 2     51289           946           718           97          40

# %%
df_sim_results = engine.top_N_similar('FireBird', None, 3)

df_sim_results
# Out:
#       name                                            address       district  \
# 63   鳥居居酒屋  17/F, Macau Yat Yuen Centre, 525 Hennessy Road...   Causeway Bay
# 69      琥酌  G/F, 159A Sai Yeung Choi Street North, Prince ...  Prince Edward
# 229     備長  26/F, Macau Yat Yuen Centre, 525 Hennessy Road...   Causeway Bay
#
#     cuisine_main_type cuisine_sub_type cuisine_minor_type  \
# 63           Japanese       Robatayaki             Skewer
# 69           Japanese       Roast Meat            Izakaya
# 229          Japanese           Skewer            Izakaya
#
#                                    available_condition price-range  rating  \
# 63   [Online Reservation, Alcoholic Drinks, May Bri...    $201-400     4.0
# 69   [Online Reservation, Alcoholic Drinks, May Bri...    $201-400     4.0
# 229  [Online Reservation, Alcoholic Drinks, May Bri...    $201-400     4.0
#
#      bookmark  review_count  review_happy  review_okay  review_sad
# 63      20823           626           545           22          29
# 69      17746           512           444           26           8
# 229     10230           368           310           21          13
